# %%
import Test_CMM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import Test_CMM
#
# File ~/Nextcloud/PHD/FWF/FWF_Project_Carotid/Test_CMM/__init__.py:2
#       1 from .uniax_CMM import *
# ----> 2 from .case_U import *
#
# File ~/Nextcloud/PHD/FWF/FWF_Project_Carotid/Test_CMM/case_U.py:1
# ----> 1 from uniax_CMM import *
#       3 import jax.numpy as jnp
#       4 from jax import jit
#
# ModuleNotFoundError: No module named 'uniax_CMM'
